# %% [markdown]
# SIMPLE LAYER TEST for Google Colab

# %%
# Define functions to connect to Google and change directories
def connectDrive():
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

def changeDirectory(path):
    import os
    original_path = os.getcwd()
    os.chdir(path)
    new_path = os.getcwd()
    print("Original path: ",original_path)
    print("New path: ",new_path)

# Connect to Google Drive
connectDrive()

# Change path
changeDirectory("/content/drive/My Drive/")
# Out:
# Mounted at /content/drive
# Original path:  /content
# New path:  /content/drive/My Drive

# %%
# !git clone https://github.com/katsuhiko-matsumoto/deep-learning-from-scratch-simple_layer_test.git
# Out:
# Cloning into 'deep-learning-from-scratch-simple_layer_test'...
# remote: Enumerating objects: 603, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 603 (delta 38), reused 77 (delta 32), pack-reused 514 (from 1)
# Receiving objects: 100% (603/603), 13.64 MiB | 13.53 MiB/s, done.
# Resolving deltas: 100% (315/315), done.

# %%
changeDirectory("/content/drive/My Drive/deep-learning-from-scratch-simple_layer_test")
# Out:
# Original path:  /content/drive/MyDrive
# New path:  /content/drive/My Drive/deep-learning-from-scratch-simple_layer_test

# %%
pwd
# Out:
# '/content/drive/My Drive/deep-learning-from-scratch-simple_layer_test'

# %% [markdown]
# 01 simple affine

# %%
# !python 01_simple_affine_main.py

# %% [markdown]
# 02 simple conv

# %%
# !python 02_simple_conv_main.py

# %% [markdown]
# 03 simple cbow

# %%
# !python 03_simple_cbow_main.py

# %% [markdown]
# 04 simple rnn

# %%
# !python 04_simple_rnn_main.py

# %% [markdown]
# 05 simple lstm

# %%
# !python 05_simple_lstm_main.py
