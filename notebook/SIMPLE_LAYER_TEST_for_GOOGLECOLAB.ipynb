# %% [markdown]
# SIMPLE LAYER TEST for Google Colab

# %%
# Define functions to connect to Google and change directories
def connectDrive():
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

def changeDirectory(path):
    import os
    original_path = os.getcwd()
    os.chdir(path)
    new_path = os.getcwd()
    print("Original path: ",original_path)
    print("New path: ",new_path)

# Connect to Google Drive
connectDrive()

# Change path
changeDirectory("/content/drive/My Drive/")

# %%
pip install cupy-cuda11x

# %%
# !git clone https://github.com/katsuhiko-matsumoto/deep-learning-from-scratch-simple_layer_test.git

# %%
changeDirectory("/content/drive/My Drive/deep-learning-from-scratch-simple_layer_test")

# %%
pwd

# %% [markdown]
# 01 simple affine

# %%
# !python 01_simple_affine_main.py

# %% [markdown]
# 02 simple conv

# %%
# !python 02_simple_conv_main.py

# %% [markdown]
# 03 simple cbow

# %%
# !python 03_simple_cbow_main.py

# %% [markdown]
# 04 simple rnn

# %%
# !python 04_simple_rnn_main.py
# Out:
# ...
# Done
# corpus size: 1000, vocabulary size: 418
# | epoch 1 | perplexity 371.46
# | epoch 2 | perplexity 245.09
# | epoch 3 | perplexity 218.27
# | epoch 4 | perplexity 212.38
# | epoch 5 | perplexity 204.43
# | epoch 6 | perplexity 201.22
# | epoch 7 | perplexity 198.30
# | epoch 8 | perplexity 196.35
# | epoch 9 | perplexity 191.50
# | epoch 10 | perplexity 193.01
# | epoch 11 | perplexity 188.80
# | epoch 12 | perplexity 192.49
# | epoch 13 | perplexity 189.82
# | epoch 14 | perplexity 190.73
# | epoch 15 | perplexity 189.79
# | epoch 16 | perplexity 186.34
# | epoch 17 | perplexity 183.92
# | epoch 18 | perplexity 181.15
# | epoch 19 | perplexity 182.68
# | epoch 20 | perplexity 183.58
# | epoch 21 | perplexity 181.91
# | epoch 22 | perplexity 177.26
# | epoch 23 | perplexity 174.78
# | epoch 24 | perplexity 176.03
# | epoch 25 | perplexity 173.02
# | epoch 26 | perplexity 172.18
# | epoch 27 | perplexity 168.02
# | epoch 28 | perplexity 166.80
# | epoch 29 | perplexity 163.68
# ...

# %% [markdown]
# 05 simple lstm

# %%
# !python 05_simple_lstm_main.py
